# %%
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score, RandomizedSearchCV
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import unidecode
import matplotlib.pyplot as plt
import re

sw = stopwords.words("spanish")
snow = SnowballStemmer('spanish')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
class Word2VecFeatureExtractor(BaseEstimator, TransformerMixin):
    def __init__(self, vector_size=100, window=5, min_count=1, sg=0):
        self.vector_size = vector_size
        self.window = window
        self.min_count = min_count
        self.sg = sg
        self.model = None

    def fit(self, X, y=None):
        X = [sentence.split(' ') for sentence in X]
        self.model = Word2Vec(sentences=X, vector_size=self.vector_size, window=self.window, min_count=self.min_count, sg=self.sg,epochs=30)
        return self

    def transform(self, X):
        feature_vectors = []
        X = [sentence.split(' ') for sentence in X]
        for text in X:
            vectors = [self.model.wv[word] for word in text if word in self.model.wv.key_to_index]
            if vectors:
                feature_vectors.append(np.mean(vectors, axis=0))
            else:
                feature_vectors.append(np.zeros(self.model.vector_size))
        return np.array(feature_vectors)

def limpiar(text):
    return ' '.join([snow.stem(unidecode.unidecode(w)) for w in re.findall(r'[a-záéíóúñ]+',str(text).lower()) if (len(w)>=2) and (w not in sw)])

# %%
data = pd.read_excel('80s.xlsx')
data['Comentariomin'] = data['Comentariomin'].apply(limpiar)
data = pd.concat([data[data.EVALUACION==1],data[data.EVALUACION==5].sample(889,ignore_index=True),data[data.EVALUACION==3].sample(889,ignore_index=True)])

# %%
from sklearn.ensemble import GradientBoostingClassifier  
from sklearn.ensemble import RandomForestClassifier   
from sklearn.ensemble import ExtraTreesClassifier    
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier    
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.svm import SVC

# %%
pipelines = []
for name_1, vectorizer in [('tf',TfidfVectorizer(use_idf=False)),('tf',TfidfVectorizer(use_idf=True)),('w2v',Word2VecFeatureExtractor())]:
    sequences = []
    for name_2, model in [('gradientboosting',GradientBoostingClassifier()),('rf',RandomForestClassifier()),('extratrees',ExtraTreesClassifier()),('lr',LogisticRegression()),('dt',DecisionTreeClassifier()),('knn',KNeighborsClassifier()),('svm',SVC()),('mlp',MLPClassifier())]:
        sequences.append(Pipeline([(name_1,vectorizer),(name_2,model)]))
    pipelines.append(sequences)

# %%
vector_params = {
    'tf': {
        'max_features': [20, 50, 100, 200, None],
        'ngram_range': [(1, 1), (1, 2), (1, 3)],
        'norm': ['l1', 'l2', None],
        'max_df': [0.75, 0.85]
    },
    'w2v': {
        'vector_size': [20, 50, 100, 200, 500],
        'window': [3, 5],
        'min_count': [1, 5, 10],
        'sg': [0, 1]
    }
}

model_params = {
    "gradientboosting": {
        'n_estimators': [50, 100, 200, 300],
        'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
        'max_depth': [None, 10, 20, 30, 50, 100],
        'subsample': [0.6, 0.8, 1.0],
        'min_samples_split': [2, 5, 10, 30, 50],
        'min_samples_leaf': [1, 2, 4, 8, 15, 30, 50],
        'max_features': ['sqrt', 'log2', None]
    },
    "rf": {
        'n_estimators': [100, 200, 300, 500],
        'max_depth': [None, 10, 20, 30, 50, 100],
        'min_samples_split': [2, 5, 10, 30, 50],
        'min_samples_leaf': [1, 2, 4, 8, 15, 30, 50],
        'max_features': ['sqrt', 'log2', None],
        'bootstrap': [True, False]
    },
    "extratrees": {
        'n_estimators': [100, 200, 300, 500],
        'max_depth': [None, 10, 20, 30, 50, 100],
        'min_samples_split': [2, 5, 10, 30, 50],
        'min_samples_leaf': [1, 2, 4, 8, 15, 30, 50],
        'max_features': ['sqrt', 'log2', None],
        'bootstrap': [True, False]
    },
    "lr": {
        'C': [0.01, 0.1, 1, 10, 100],
        'solver': ['liblinear', 'lbfgs', 'saga'],
        'penalty': ['l1', 'l2', 'elasticnet', None],
        'max_iter': [100, 200, 500, 1000]
    },
    "dt": {
        'criterion': ['gini', 'entropy', 'log_loss'],
        'max_depth': [None, 10, 20, 30, 50, 100],
        'min_samples_split': [2, 5, 10, 30, 50],
        'min_samples_leaf': [1, 2, 4, 8, 15, 30, 50],
        'max_features': ['sqrt', 'log2', None]
    },
    "knn": {
        'n_neighbors': [3, 5, 10, 20],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan', 'minkowski'],
        'p': [1, 2]
    },
    "svm": {
        'C': [0.1, 1, 10, 100],
        'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
        'degree': [2, 3, 4],
        'gamma': ['scale', 'auto'],
        'shrinking': [True, False]
    },
    "mlp": {
        "hidden_layer_sizes": [(50,), (100,), (50, 50), (100, 100)],
        "activation": ["tanh", "relu"],
        "solver": ["adam", "sgd"],
        "alpha": [0.0001, 0.001, 0.01],
        "learning_rate": ["constant", "adaptive"],
        "learning_rate_init": [0.001, 0.01],
        "max_iter": [200, 500],
        "batch_size": ["auto", 64, 128]
    }
}

x = {}
x.update(vector_params)
x.update(model_params)

params = {}
for key, embeds in x.items():
    for subkey, distribs in embeds.items():
        params.update({f'{key}__{subkey}':distribs})

def get_distrib(pipe):
    tmp_dict = {}
    for key, values in params.items():
        if key in pipe.get_params().keys():
            tmp_dict.update({key:values})
    return tmp_dict

# %%
X_T, X_t, Y_T, Y_t = train_test_split(data.Comentariomin,data.EVALUACION,test_size=0.2,random_state=42,shuffle=True,stratify=data.EVALUACION)

# %%
def training(pipe):
    kfold = KFold(n_splits=10, random_state=42, shuffle= True)
    T_results = []
    t_results = []
    hyperparams = []
    for subpipe in pipe:
         print(f'Training {list(subpipe.named_steps.keys())}')
         subparams = get_distrib(subpipe)
         rs = RandomizedSearchCV(
             subpipe,
             param_distributions=subparams,
             n_iter=30,
             scoring='accuracy',
             cv=5
         )
         rs.fit(X_T,Y_T)
         best = rs.best_estimator_
         
         train_acc = cross_val_score(best,X_T,Y_T,cv=kfold,scoring='accuracy')
         test_acc = accuracy_score(Y_t,best.predict(X_t))
         best_params = rs.best_params_
         
         T_results.append(train_acc)
         t_results.append(test_acc)
         hyperparams.append(best_params)
         
         print(f"""Best hyperparameters: {best_params}
Train Acc: {train_acc.mean():.4f} ({train_acc.std():.4f})
Test Acc: {test_acc}\n""")
         
    return T_results, t_results, hyperparams

def compute_boxes(T_results, t_results, title):
    models = ['gradientboosting','rf','extratrees','lr','dt','knn','svm','mlp']
    labels = [f"{tag}\n({t_results[i]*100:.2f}%)" for i,tag in enumerate(models)]
    
    fig = plt.figure(figsize=[10,7])
    fig.suptitle(title)
    ax = fig.add_subplot(111)
    plt.boxplot(T_results)
    ax.set_xticklabels(labels)
    plt.show()

# %% [markdown]
# ### Word2Vec

# %%
w2v = pipelines[2]
T_results, t_results, hyperparams = training(w2v)
compute_boxes(T_results,t_results,'10-fold-CV accuracy for W2V vectorizer')
# Out:
# Training ['w2v', 'gradientboosting']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 200, 'w2v__sg': 1, 'w2v__min_count': 5, 'gradientboosting__subsample': 0.6, 'gradientboosting__n_estimators': 300, 'gradientboosting__min_samples_split': 5, 'gradientboosting__min_samples_leaf': 8, 'gradientboosting__max_features': 'sqrt', 'gradientboosting__max_depth': 10, 'gradientboosting__learning_rate': 0.1}
# Train Acc: 0.7182 (0.0223)
# Test Acc: 0.7715355805243446
#
# Training ['w2v', 'rf']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 500, 'w2v__sg': 1, 'w2v__min_count': 5, 'rf__n_estimators': 100, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 4, 'rf__max_features': None, 'rf__max_depth': 20, 'rf__bootstrap': True}
# Train Acc: 0.7159 (0.0281)
# Test Acc: 0.7228464419475655
#
# Training ['w2v', 'extratrees']
# Best hyperparameters: {'w2v__window': 3, 'w2v__vector_size': 200, 'w2v__sg': 1, 'w2v__min_count': 10, 'extratrees__n_estimators': 100, 'extratrees__min_samples_split': 10, 'extratrees__min_samples_leaf': 1, 'extratrees__max_features': None, 'extratrees__max_depth': 10, 'extratrees__bootstrap': False}
# Train Acc: 0.7051 (0.0355)
# Test Acc: 0.7415730337078652
#
# Training ['w2v', 'lr']
# Best hyperparameters: {'w2v__window': 3, 'w2v__vector_size': 500, 'w2v__sg': 0, 'w2v__min_count': 10, 'lr__solver': 'lbfgs', 'lr__penalty': None, 'lr__max_iter': 500, 'lr__C': 0.1}
# Train Acc: 0.7135 (0.0252)
# Test Acc: 0.7359550561797753
#
# Training ['w2v', 'dt']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 100, 'w2v__sg': 1, 'w2v__min_count': 10, 'dt__min_samples_split': 5, 'dt__min_samples_leaf': 50, 'dt__max_features': None, 'dt__max_depth': 10, 'dt__criterion': 'gini'}
# Train Acc: 0.6319 (0.0393)
# Test Acc: 0.6797752808988764
#
# Training ['w2v', 'knn']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 50, 'w2v__sg': 1, 'w2v__min_count': 10, 'knn__weights': 'distance', 'knn__p': 1, 'knn__n_neighbors': 10, 'knn__metric': 'minkowski'}
# Train Acc: 0.6844 (0.0370)
# Test Acc: 0.7303370786516854
#
# Training ['w2v', 'svm']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 100, 'w2v__sg': 1, 'w2v__min_count': 10, 'svm__shrinking': False, 'svm__kernel': 'poly', 'svm__gamma': 'scale', 'svm__degree': 3, 'svm__C': 10}
# Train Acc: 0.7173 (0.0300)
# Test Acc: 0.7509363295880149
#
# Training ['w2v', 'mlp']
# Best hyperparameters: {'w2v__window': 3, 'w2v__vector_size': 200, 'w2v__sg': 1, 'w2v__min_count': 1, 'mlp__solver': 'adam', 'mlp__max_iter': 200, 'mlp__learning_rate_init': 0.001, 'mlp__learning_rate': 'adaptive', 'mlp__hidden_layer_sizes': (50,), 'mlp__batch_size': 128, 'mlp__alpha': 0.0001, 'mlp__activation': 'tanh'}
# Train Acc: 0.7173 (0.0289)
# Test Acc: 0.7509363295880149

# %% [markdown]
# ### Estandarizando

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
std_w2v = pipelines[2]

for i,pipe in enumerate(std_w2v):
    steps = pipe.steps
    steps.insert(1,('scaler',StandardScaler(with_mean=False)))
    std_w2v[i].steps = steps

T_results_std, t_results_std, hyperparams_std = training(std_w2v)
compute_boxes(T_results_std,t_results_std,'10-fold-CV accuracy for Standardized W2V vectorizer')
# Out:
# Training ['w2v', 'scaler', 'gradientboosting']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 50, 'w2v__sg': 1, 'w2v__min_count': 5, 'gradientboosting__subsample': 0.6, 'gradientboosting__n_estimators': 300, 'gradientboosting__min_samples_split': 10, 'gradientboosting__min_samples_leaf': 8, 'gradientboosting__max_features': 'sqrt', 'gradientboosting__max_depth': None, 'gradientboosting__learning_rate': 0.2}
# Train Acc: 0.7163 (0.0240)
# Test Acc: 0.7209737827715356
#
# Training ['w2v', 'scaler', 'rf']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 200, 'w2v__sg': 1, 'w2v__min_count': 5, 'rf__n_estimators': 200, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 15, 'rf__max_features': 'sqrt', 'rf__max_depth': 10, 'rf__bootstrap': False}
# Train Acc: 0.7037 (0.0407)
# Test Acc: 0.7340823970037453
#
# Training ['w2v', 'scaler', 'extratrees']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 500, 'w2v__sg': 1, 'w2v__min_count': 5, 'extratrees__n_estimators': 300, 'extratrees__min_samples_split': 30, 'extratrees__min_samples_leaf': 15, 'extratrees__max_features': None, 'extratrees__max_depth': 100, 'extratrees__bootstrap': False}
# Train Acc: 0.7098 (0.0333)
# Test Acc: 0.7397003745318352
#
# Training ['w2v', 'scaler', 'lr']
# Best hyperparameters: {'w2v__window': 3, 'w2v__vector_size': 500, 'w2v__sg': 1, 'w2v__min_count': 5, 'lr__solver': 'lbfgs', 'lr__penalty': None, 'lr__max_iter': 200, 'lr__C': 0.01}
# Train Acc: 0.7032 (0.0221)
# Test Acc: 0.7322097378277154
#
# Training ['w2v', 'scaler', 'dt']
# Best hyperparameters: {'w2v__window': 3, 'w2v__vector_size': 100, 'w2v__sg': 1, 'w2v__min_count': 10, 'dt__min_samples_split': 2, 'dt__min_samples_leaf': 30, 'dt__max_features': None, 'dt__max_depth': 100, 'dt__criterion': 'gini'}
# Train Acc: 0.6409 (0.0295)
# Test Acc: 0.6310861423220974
#
# Training ['w2v', 'scaler', 'knn']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 20, 'w2v__sg': 1, 'w2v__min_count': 10, 'knn__weights': 'distance', 'knn__p': 2, 'knn__n_neighbors': 5, 'knn__metric': 'minkowski'}
# Train Acc: 0.6783 (0.0371)
# Test Acc: 0.7172284644194756
#
# Training ['w2v', 'scaler', 'svm']
# Best hyperparameters: {'w2v__window': 5, 'w2v__vector_size': 500, 'w2v__sg': 1, 'w2v__min_count': 10, 'svm__shrinking': True, 'svm__kernel': 'poly', 'svm__gamma': 'scale', 'svm__degree': 2, 'svm__C': 100}
# Train Acc: 0.7196 (0.0342)
# Test Acc: 0.7415730337078652
#
# Training ['w2v', 'scaler', 'mlp']
# Best hyperparameters: {'w2v__window': 3, 'w2v__vector_size': 100, 'w2v__sg': 1, 'w2v__min_count': 5, 'mlp__solver': 'sgd', 'mlp__max_iter': 500, 'mlp__learning_rate_init': 0.001, 'mlp__learning_rate': 'constant', 'mlp__hidden_layer_sizes': (50,), 'mlp__batch_size': 'auto', 'mlp__alpha': 0.001, 'mlp__activation': 'tanh'}
# Train Acc: 0.7238 (0.0327)
# Test Acc: 0.7640449438202247
